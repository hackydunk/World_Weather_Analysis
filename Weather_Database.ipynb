# %%
# %matplotlib inline
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np

# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1faa1314e11327f81d624275c9bcd26c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    #print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # I don't actually need the try except block here since i'm checking
        # the weather main status first
        try:      
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
            print('It is not raining!')
            pass

        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
            print('It is not snowing!')
            pass               



        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow

                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# City not found. Skipping...
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not raining!
# It is not snowing!
# It is not raining!
# It is not snowing!
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0  Mountain Home      US  2020-01-06 04:41:06  43.13 -115.69     33.80
# 1      Jamestown      AU  2020-01-06 04:36:37 -33.21  138.60     75.81
# 2         Touros      BR  2020-01-06 04:37:03  -5.20  -35.46     78.80
# 3       Khandyga      RU  2020-01-06 04:39:41  62.65  135.58     -2.34
# 4        Gigmoto      PH  2020-01-06 04:38:13  13.78  124.39     80.29
# 5         Vostok      RU  2020-01-06 04:38:45  46.45  135.83     10.69
# 6    Yellowknife      CA  2020-01-06 04:35:49  62.45 -114.38    -18.00
# 7        Leiyang      CN  2020-01-06 04:43:49  26.42  112.85     79.07
# 8      Cape Town      ZA  2020-01-06 04:32:44 -33.93   18.42     64.00
# 9       Cabedelo      BR  2020-01-06 04:43:49  -6.97  -34.84     78.80
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        80          40        8.61    scattered clouds
# 1        49          84        6.93       broken clouds
# 2        83          40        3.36    scattered clouds
# 3        97         100        3.78          light snow
# 4        81          85       21.88          light rain
# 5        89          20        2.55          few clouds
# 6        75           5        6.93           clear sky
# 7        46          17       10.18          few clouds
# 8        72          20        8.05          few clouds
# 9        83          20        3.36          few clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                      0.00
# 1                      0.00                      0.00
# 2                      0.00                      0.00
# 3                      0.00                      0.25
# 4                      2.87                      0.00
# 5                      0.00                      0.00
# 6                      0.00                      0.00
# 7                      0.00                      0.00
# 8                      0.00                      0.00
# 9                      0.00                      0.00

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# count the number of cities with rain and snowfall
city_data_df.astype(bool).sum(axis=0)
# Out:
# City                        565
# Country                     565
# Date                        565
# Lat                         565
# Lng                         565
# Max Temp                    565
# Humidity                    565
# Cloudiness                  494
# Wind Speed                  565
# Current Description         565
# Rain inches (last 3 hrs)     51
# Snow inches (last 3 hrs)     32
# dtype: int64
